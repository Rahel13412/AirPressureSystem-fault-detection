# %%
print('hello ')
# Out:
# hello

# %%
import pandas as pd

# %%
df = pd.read_csv('/config/workspace/artifact/09282023__100941/data_ingestion/dataset/train.csv')

# %%
df.isnull().sum()
# Out:
# class         0
# aa_000        0
# ab_000    22358
# ac_000     1723
# ad_000     7413
#           ...
# ee_007      305
# ee_008      305
# ee_009      305
# ef_000     1398
# eg_000     1397
# Length: 171, dtype: int64

# %%
(df.isnull().sum()/df.shape[0]).values
# Out:
# array([0.        , 0.        , 0.77229706, 0.05951641, 0.25606218,
#        0.04431779, 0.04431779, 0.01053541, 0.01053541, 0.01053541,
#        0.01053541, 0.01053541, 0.01053541, 0.01053541, 0.01053541,
#        0.01053541, 0.01053541, 0.01098446, 0.01074266, 0.01074266,
#        0.0784456 , 0.01088083, 0.01074266, 0.01088083, 0.00974093,
#        0.01088083, 0.00974093, 0.04825561, 0.01074266, 0.01074266,
#        0.01074266, 0.04435233, 0.04435233, 0.01053541, 0.01053541,
#        0.01053541, 0.01053541, 0.01053541, 0.01053541, 0.01053541,
#        0.01053541, 0.01053541, 0.01053541, 0.01053541, 0.01053541,
#        0.01053541, 0.01053541, 0.01053541, 0.01053541, 0.01053541,
#        0.01053541, 0.01053541, 0.01053541, 0.01074266, 0.01074266,
#        0.01074266, 0.01074266, 0.01074266, 0.01074266, 0.01074266,
#        0.01074266, 0.01074266, 0.01074266, 0.01098446, 0.04829016,
#        0.04829016, 0.04438687, 0.04431779, 0.01088083, 0.01088083,
# ...

# %%
(df.isnull().sum()/df.shape[0]).index
# Out:
# Index(['class', 'aa_000', 'ab_000', 'ac_000', 'ad_000', 'ae_000', 'af_000',
#        'ag_000', 'ag_001', 'ag_002',
#        ...
#        'ee_002', 'ee_003', 'ee_004', 'ee_005', 'ee_006', 'ee_007', 'ee_008',
#        'ee_009', 'ef_000', 'eg_000'],
#       dtype='object', length=171)

# %%
drop_colums_names = []
for column_name,missing_percentage in zip((df.isnull().sum()/df.shape[0]).index,(df.isnull().sum()/df.shape[0]).values):
    print(column_name,round(missing_percentage*100,2))
    if missing_percentage>0.3:
        drop_colums_names.append(column_name)
# Out:
# class 0.0
# aa_000 0.0
# ab_000 77.23
# ac_000 5.95
# ad_000 25.61
# ae_000 4.43
# af_000 4.43
# ag_000 1.05
# ag_001 1.05
# ag_002 1.05
# ag_003 1.05
# ag_004 1.05
# ag_005 1.05
# ag_006 1.05
# ag_007 1.05
# ag_008 1.05
# ag_009 1.05
# ah_000 1.1
# ai_000 1.07
# aj_000 1.07
# ak_000 7.84
# al_000 1.09
# am_0 1.07
# an_000 1.09
# ao_000 0.97
# ap_000 1.09
# aq_000 0.97
# ar_000 4.83
# as_000 1.07
# at_000 1.07
# au_000 1.07
# av_000 4.44
# ax_000 4.44
# ay_000 1.05
# ay_001 1.05
# ay_002 1.05
# ay_003 1.05
# ay_004 1.05
# ay_005 1.05
# ay_006 1.05
# ay_007 1.05
# ay_008 1.05
# ay_009 1.05
# az_000 1.05
# az_001 1.05
# az_002 1.05
# az_003 1.05
# az_004 1.05
# az_005 1.05
# az_006 1.05
# az_007 1.05
# az_008 1.05
# az_009 1.05
# ba_000 1.07
# ba_001 1.07
# ba_002 1.07
# ba_003 1.07
# ba_004 1.07
# ba_005 1.07
# ba_006 1.07
# ba_007 1.07
# ba_008 1.07
# ba_009 1.07
# bb_000 1.1
# bc_000 4.83
# bd_000 4.83
# be_000 4.44
# bf_000 4.43
# bg_000 1.09
# bh_000 1.09
# bi_000 0.97
# ...

# %%
drop_colums_names
# Out:
# ['ab_000',
#  'bk_000',
#  'bl_000',
#  'bm_000',
#  'bn_000',
#  'bo_000',
#  'bp_000',
#  'bq_000',
#  'br_000',
#  'cr_000']
